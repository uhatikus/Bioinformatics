# %%
import pandas as pd
import sys 
# !{sys.executable} -m pip install openpyxl
import openpyxl
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Looking in indexes: https://pypi.org/simple, https://alexander.ukhatov:****@pypi.pkg.jetbrains.space/glassdomeinc/p/ai/forecast-anomaly-data-science/simple
# ...
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip

# %%
cgga_data_mRNA_array = pd.read_csv("cgga_data_mRNA_array.txt", sep='\t')
cgga_data_mRNA_array.index = cgga_data_mRNA_array["bcr_patient_barcode"]
# tcga_lgg_data.rename(columns=lambda x: x.replace('-', '.'), inplace=True)
cgga_data_mRNAseq = pd.read_csv("cgga_data_mRNAseq.txt", sep='\t')
cgga_data_mRNAseq.index = cgga_data_mRNAseq["bcr_patient_barcode"]
# tcga_lgg_data_old.rename(index=lambda x: x.replace('-', '.'), inplace=True)

# %%
cgga_data_mRNA_array
# Out:
#                     tcga_subtypes   prs_type histology    grade  gender  \
# bcr_patient_barcode
# CGGA_253                Proneural    Primary         A   WHO II  Female
# CGGA_256                   Neural    Primary         A   WHO II    Male
# CGGA_258              Mesenchymal    Primary         A   WHO II  Female
# CGGA_267                   Neural    Primary         A   WHO II    Male
# CGGA_271                   Neural    Primary         A   WHO II    Male
# ...                           ...        ...       ...      ...     ...
# CGGA_406                Classical  Recurrent       rAA  WHO III  Female
# CGGA_492              Mesenchymal  Recurrent       rAA  WHO III    Male
# CGGA_704                Proneural    Primary         A   WHO II    Male
# CGGA_1061               Proneural  Recurrent       rAA  WHO III  Female
# CGGA_703                   Neural  Recurrent       rAO  WHO III  Female
#
#                      age_at_initial_pathologic_diagnosis    time  alive  \
# ...

# %%
cgga_data_mRNAseq
# Out:
#                       prs_type histology    grade  gender  \
# bcr_patient_barcode
# CGGA_1006              Primary        AA  WHO III    Male
# CGGA_1022            Recurrent        rA   WHO II  Female
# CGGA_1034              Primary        AA  WHO III    Male
# CGGA_1052              Primary         O   WHO II    Male
# CGGA_1079              Primary        AA  WHO III    Male
# ...                        ...       ...      ...     ...
# CGGA_1118            Recurrent       rAA  WHO III    Male
# CGGA_1246              Primary        AO  WHO III    Male
# CGGA_243               Primary         O   WHO II  Female
# CGGA_247               Primary        AA  WHO III    Male
# CGGA_738               Primary         A   WHO II    Male
#
#                      age_at_initial_pathologic_diagnosis    time  alive  \
# bcr_patient_barcode
# CGGA_1006                                             42   254.0    1.0
# CGGA_1022                                             62   518.0    0.0
# ...

# %%
a = cgga_data_mRNA_array.loc[(r for r in cgga_data_mRNAseq.index if r in cgga_data_mRNA_array.index)]
b = cgga_data_mRNAseq.loc[(r for r in cgga_data_mRNA_array.index if r in cgga_data_mRNAseq.index)]

# %%
a
# Out:
#                     tcga_subtypes   prs_type histology    grade  gender  \
# bcr_patient_barcode
# CGGA_1006             Mesenchymal    Primary        AA  WHO III    Male
# CGGA_1022             Mesenchymal  Recurrent        rA   WHO II  Female
# CGGA_1081               Proneural  Recurrent       rAA  WHO III  Female
# CGGA_323                   Neural    Primary         O   WHO II  Female
# CGGA_330              Mesenchymal    Primary        AA  WHO III    Male
# CGGA_541                   Neural    Primary         A   WHO II  Female
# CGGA_564                   Neural    Primary        AA  WHO III    Male
# CGGA_578                Proneural    Primary        AA  WHO III  Female
# CGGA_633                Proneural    Primary         O   WHO II  Female
# CGGA_643                Proneural    Primary        AA  WHO III    Male
# CGGA_659                   Neural    Primary         O   WHO II  Female
# CGGA_661              Mesenchymal    Primary        AA  WHO III    Male
# ...

# %%
# cols = [col[:-6] for col in tcga_lgg_data.columns if "median" in col]

# %%
# medians = tcga_lgg_data[cols].median()
# for col in cols:
#     new_col_name = col + 'median'
#     print(sum(((tcga_lgg_data[col] > medians[col]).astype(int) == tcga_lgg_data[new_col_name]).astype(int)))

# %%
cgga_data_mRNA_array["DMRT3median"].sort_index()
# Out:
# bcr_patient_barcode
# CGGA_1005      1
# CGGA_1006      1
# CGGA_1022      0
# CGGA_1027      0
# CGGA_1046-1    1
#               ..
# CGGA_856       0
# CGGA_868       0
# CGGA_898       0
# CGGA_D39       1
# CGGA_D46       0
# Name: DMRT3median, Length: 174, dtype: int64

# %%
cgga_data_mRNAseq["DMRT3median"].sort_index()
# Out:
# bcr_patient_barcode
# CGGA_1004    0
# CGGA_1005    1
# CGGA_1006    1
# CGGA_1013    0
# CGGA_1020    0
#             ..
# CGGA_J023    0
# CGGA_J024    0
# CGGA_J030    0
# CGGA_J042    0
# CGGA_J130    1
# Name: DMRT3median, Length: 182, dtype: int64

# %%
(abs(a.sort_index()["AKR1E2median"]-b.sort_index()["AKR1E2median"])).sum() / len(a.index)
# Out:
# 0.4318181818181818

# %%
(abs(a.sort_index()["DMRT3median"]-b.sort_index()["DMRT3median"])).sum() / len(a.index)
# Out:
# 0.3409090909090909

# %%
(abs(a.sort_index()["CBX3median"]-b.sort_index()["CBX3median"])).sum() / len(a.index)
# Out:
# 0.11363636363636363

# %%
(abs(a.sort_index()["PIM1median"]-b.sort_index()["PIM1median"])).sum() / len(a.index)
# Out:
# 0.045454545454545456
