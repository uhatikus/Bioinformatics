# %%
import pandas as pd
import sys 
# !{sys.executable} -m pip install openpyxl
import openpyxl
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Looking in indexes: https://pypi.org/simple, https://alexander.ukhatov:****@pypi.pkg.jetbrains.space/glassdomeinc/p/ai/forecast-anomaly-data-science/simple
# ...
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip

# %%
tcga_lgg_data = pd.read_csv("tcga_lgg_data.txt", sep='\t')
tcga_lgg_data.index = tcga_lgg_data["bcr_patient_barcode"]
tcga_lgg_data.rename(columns=lambda x: x.replace('-', '.'), inplace=True)
tcga_lgg_data_old = pd.read_csv("tcga_lgg_data_old.txt", sep='\t')
tcga_lgg_data_old.index = tcga_lgg_data_old["bcr_patient_barcode"]
tcga_lgg_data_old.rename(index=lambda x: x.replace('-', '.'), inplace=True)

# %%
tcga_lgg_data
# Out:
#                             histology recurrence grade           subtype  \
# bcr_patient_barcode
# TCGA.CS.4938              Astrocytoma    Primary    II  IDHmut-non-codel
# TCGA.CS.4941              Astrocytoma    Primary   III             IDHwt
# TCGA.CS.4942              Astrocytoma    Primary   III  IDHmut-non-codel
# TCGA.CS.4943              Astrocytoma    Primary   III  IDHmut-non-codel
# TCGA.CS.4944              Astrocytoma    Primary    II  IDHmut-non-codel
# ...                               ...        ...   ...               ...
# TCGA.WY.A85A              Astrocytoma    Primary    II               NaN
# TCGA.WY.A85B              Astrocytoma    Primary    II               NaN
# TCGA.WY.A85C              Astrocytoma    Primary    II               NaN
# TCGA.WY.A85D         Oligoastrocytoma    Primary    II               NaN
# TCGA.WY.A85E         Oligoastrocytoma    Primary    II               NaN
#
# ...

# %%
tcga_lgg_data_old
# Out:
#                      histological_type other_dx  gender vital_status  \
# bcr_patient_barcode
# TCGA.HT.7688         Oligodendroglioma       No    MALE        Alive
# TCGA.DU.6401         Oligodendroglioma       No  FEMALE         Dead
# TCGA.S9.A6U6               Astrocytoma       No    MALE        Alive
# TCGA.CS.4941               Astrocytoma       No    MALE         Dead
# TCGA.HW.A5KK               Astrocytoma       No    MALE        Alive
# ...                                ...      ...     ...          ...
# TCGA.HT.7476               Astrocytoma       No    MALE        Alive
# TCGA.FG.8181          Oligoastrocytoma       No    MALE        Alive
# TCGA.DU.8158               Astrocytoma       No  FEMALE         Dead
# TCGA.HT.A5RC               Astrocytoma       No  FEMALE         Dead
# TCGA.HW.8320               Astrocytoma       No    MALE        Alive
#
#                      days_to_birth  days_to_last_known_alive  days_to_death  \
# bcr_patient_barcode
# ...

# %%
a = tcga_lgg_data_old.loc[(r for r in tcga_lgg_data.index if r in tcga_lgg_data_old.index)]
b = tcga_lgg_data.loc[(r for r in tcga_lgg_data_old.index if r in tcga_lgg_data.index)]

# %%
b
# Out:
#                              histology recurrence grade           subtype  \
# bcr_patient_barcode
# TCGA.HT.7688         Oligodendroglioma    Primary   III  IDHmut-non-codel
# TCGA.DU.6401         Oligodendroglioma    Primary    II  IDHmut-non-codel
# TCGA.S9.A6U6               Astrocytoma    Primary   III               NaN
# TCGA.CS.4941               Astrocytoma    Primary   III             IDHwt
# TCGA.HW.A5KK               Astrocytoma    Primary   III             IDHwt
# ...                                ...        ...   ...               ...
# TCGA.HT.7476               Astrocytoma    Primary    II  IDHmut-non-codel
# TCGA.FG.8181          Oligoastrocytoma    Primary   III             IDHwt
# TCGA.DU.8158               Astrocytoma    Primary   III             IDHwt
# TCGA.HT.A5RC               Astrocytoma    Primary   III             IDHwt
# TCGA.HW.8320               Astrocytoma    Primary   III  IDHmut-non-codel
#
# ...

# %%
# cols = [col[:-6] for col in tcga_lgg_data.columns if "median" in col]

# %%
# medians = tcga_lgg_data[cols].median()
# for col in cols:
#     new_col_name = col + 'median'
#     print(sum(((tcga_lgg_data[col] > medians[col]).astype(int) == tcga_lgg_data[new_col_name]).astype(int)))

# %%
tcga_lgg_data["AKR1E2median"].sort_index()
# Out:
# bcr_patient_barcode
# TCGA.CS.4938    1
# TCGA.CS.4941    0
# TCGA.CS.4942    1
# TCGA.CS.4943    0
# TCGA.CS.4944    0
#                ..
# TCGA.WY.A85A    0
# TCGA.WY.A85B    0
# TCGA.WY.A85C    0
# TCGA.WY.A85D    1
# TCGA.WY.A85E    1
# Name: AKR1E2median, Length: 513, dtype: int64

# %%
tcga_lgg_data_old["AKR1E2median"].sort_index()
# Out:
# bcr_patient_barcode
# TCGA-CS-4938    1
# TCGA-CS-4941    0
# TCGA-CS-4942    1
# TCGA-CS-4943    1
# TCGA-CS-4944    0
#                ..
# TCGA-WY-A85A    1
# TCGA-WY-A85B    0
# TCGA-WY-A85C    0
# TCGA-WY-A85D    1
# TCGA-WY-A85E    1
# Name: AKR1E2median, Length: 515, dtype: int64

# %%
(abs(a.sort_index()["AKR1E2median"]-b.sort_index()["AKR1E2median"])).sum()
# Out:
# 276
