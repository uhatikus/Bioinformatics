# %%
import pandas as pd
import numpy as np
import sys 
# !{sys.executable} -m pip install openpyxl
import openpyxl
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Looking in indexes: https://pypi.org/simple, https://alexander.ukhatov:****@pypi.pkg.jetbrains.space/glassdomeinc/p/ai/forecast-anomaly-data-science/simple
# ...
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip

# %%
cgga_data_mRNA_array = pd.read_csv("CGGA.mRNA_array_301_gene_level.20200506.txt", sep='\t')
cgga_data_mRNA_array.set_index("Gene_Name", inplace=True)
cgga_data_mRNA_array = cgga_data_mRNA_array.transpose()
cgga_data_mRNA_array.index.name = "Sample"
# cgga_data.set_index("Sample", inplace=True)

# %%
# cgga_data_mRNAseq.to_csv('cgga_data_mRNAseq.txt', sep='\t', index=False)

# %%
cgga_data_mRNA_array
# Out:
# Gene_Name      A1BG      A1CF     A2BP1     A2LD1       A2M     A2ML1  \
# Sample
# CGGA_11   -0.360363  2.341360  0.034519 -0.913056 -2.248643  1.210290
# CGGA_124   0.564952  1.170794  1.096407  0.510880 -1.875580  2.135452
# CGGA_126   0.304772  2.208151  0.302488  0.425367 -3.310851  1.633288
# CGGA_168   0.174914  0.965229  0.094911 -0.194938  1.564424 -0.256463
# CGGA_172   0.337038 -0.686878 -0.391238  0.436841  0.932857 -0.896066
# ...             ...       ...       ...       ...       ...       ...
# CGGA_719  -0.722863 -0.369550  2.221534 -0.227890 -0.709499 -0.042163
# CGGA_798   0.339448 -0.190751 -0.532497  0.401836 -0.021969  0.028231
# CGGA_822   0.727074 -1.250787 -0.202966 -1.145227 -0.416451 -0.027148
# CGGA_899   0.687279 -0.683125  0.497587 -0.236199  0.157047 -1.268045
# CGGA_1068 -0.670908  2.395515 -0.448775 -1.149725  1.083235  1.313138
#
# Gene_Name    A4GALT     A4GNT      AAAS      AACS  ...  hCG_20426  \
# ...

# %%
# [name for name in cgga_data.columns if "GC0" in name]

# %%
# "FABP1" in cgga_data.columns

# %%
genes = list(set(list(pd.read_excel('gene_list.xlsx', sheet_name=0, header=None)[0]) +\
    list(pd.read_excel('gene_list.xlsx', sheet_name=1, header=None)[0])+\
    list(pd.read_excel('gene_list.xlsx', sheet_name=2, header=None)[0])))

# %%
print(len(genes), "genes: ", genes)
# Out:
# 87 genes:  ['RAF1', 'KRT31', 'HTR1B', 'MYC', 'SLC12A7', 'TIE1', 'TP53TG5', 'APP', 'RLBP1', 'GPR3', 'SPRY4', 'AQP1', 'CFTR', 'SLC9A3R2', 'GNG12', 'SPSB1', 'ALDH8A1', 'CCM2L', 'ESR1', 'PPP5C', 'SHC3', 'KRT19', 'PTGDR2', 'MT-ND6', 'MT-ND3', 'KRT5', 'IGF2BP3', 'ITPR3', 'AKR1E2', 'SKIL', 'ETV5', 'CD3D', 'HLA-DQA1', 'ETV4', 'MET', 'FSHR', 'FABP1', 'PLP1', 'SYNJ2', 'CRHR2', 'TUBB4A', 'EVPL', 'DDRGK1', 'THBS4', 'ANXA2', 'DDIT4L', 'C11orf54', 'PENK', 'BCL2L11', 'PAX6', 'P2RY14', 'CORO6', 'DPY19L3', 'CHIT1', 'NPBWR2', 'MT-RNR2', 'MDFI', 'PREX2', 'PHLDB2', 'MYO5C', 'OXGR1', 'PSEN2', 'KCNJ12', 'GDF15', 'C1QTNF7', 'GRB14', 'BAG3', 'MPL', 'ALDH1A3', 'HNF4A', 'CKMT2', 'VAX1', 'GEM', 'PGAM2', 'THSD7A', 'LRRK2', 'ACTB', 'CBX3', 'DMRT3', 'BMP8A', 'PIM1', 'ABCC3', 'MYO1D', 'CD36', 'PTH1R', 'HTR1F', 'DLG4']

# %%
genes_in_cgga_data_mRNA_array = [g for g in genes if g in cgga_data_mRNA_array.columns]
genes_not_in_cgga_data_mRNA_array = [g for g in genes if g not in cgga_data_mRNA_array.columns]
print(f"Not in cgga_data_mRNAseq: {genes_not_in_cgga_data_mRNA_array}")
# Out:
# Not in cgga_data_mRNAseq: ['CCM2L', 'PTGDR2', 'MT-ND6', 'MT-ND3', 'PLP1', 'TUBB4A', 'MT-RNR2', 'PREX2', 'VAX1']

# %%
filtered_cgga_data_mRNA_array = cgga_data_mRNA_array[genes_in_cgga_data_mRNA_array]
filtered_cgga_data_mRNA_array = np.exp(filtered_cgga_data_mRNA_array)
filtered_cgga_data_mRNA_array
# Out:
# Gene_Name      RAF1     KRT31     HTR1B       MYC   SLC12A7      TIE1  \
# Sample
# CGGA_11    0.199899  3.851997  7.358831  0.621552  3.023564  0.305205
# CGGA_124   0.305667  2.109523  3.613475  0.743549  1.732212  0.265589
# CGGA_126   0.254286  1.983284  6.217466  1.039545  2.919919  0.201940
# CGGA_168   0.677747  0.970693  0.997041  0.848718  1.422612  0.988474
# CGGA_172   0.627815  0.686414  0.503491  1.422180  0.748785  2.496159
# ...             ...       ...       ...       ...       ...       ...
# CGGA_719   1.078383  0.819754  0.924722  0.626762  0.946109  1.071683
# CGGA_798   0.534766  1.058440  1.100992  0.990936  0.755055  0.120775
# CGGA_822   1.721614  1.199606  1.573803  1.094550  0.741663  0.427374
# CGGA_899   1.310214  1.030919  1.337792  2.343515  1.267697  0.818146
# CGGA_1068  0.987260  0.405042  1.331131  1.164522  1.182173  0.391089
#
# Gene_Name   TP53TG5       APP      RLBP1       GPR3  ...      CBX3      DMRT3  \
# ...

# %%
cgga_data_mRNA_array_pheno = pd.read_csv("CGGA.mRNA_array_301_clinical.20200506.txt", sep='\t')
# cgga_data_mRNAseq_pheno
cgga_data_mRNA_array_pheno.set_index("CGGA_ID", inplace=True)
cgga_data_mRNA_array_pheno
# Out:
#           TCGA_subtypes   PRS_type Histology   Grade  Gender   Age      OS  \
# CGGA_ID
# CGGA_11       Classical    Primary       GBM  WHO IV  Female  57.0   155.0
# CGGA_124    Mesenchymal    Primary       GBM  WHO IV    Male  53.0   414.0
# CGGA_126    Mesenchymal    Primary       GBM  WHO IV  Female  50.0  1177.0
# CGGA_168    Mesenchymal    Primary       GBM  WHO IV    Male  17.0  3086.0
# CGGA_172    Mesenchymal    Primary       GBM  WHO IV  Female  57.0   462.0
# ...                 ...        ...       ...     ...     ...   ...     ...
# CGGA_719         Neural  Secondary      sGBM  WHO IV    Male  51.0   101.0
# CGGA_798    Mesenchymal  Secondary      sGBM  WHO IV  Female  41.0   136.0
# CGGA_822      Proneural  Secondary      sGBM  WHO IV    Male  46.0  2237.0
# CGGA_899      Proneural  Recurrent      rGBM  WHO IV    Male  48.0   231.0
# CGGA_1068   Mesenchymal  Secondary      sGBM  WHO IV    Male  29.0    68.0
#
# ...

# %%
cgga_data_mRNA_array_pheno.rename(columns=lambda x: x.lower(), inplace=True)
cgga_data_mRNA_array_pheno.rename(columns={'os': 'time', 'age': 'age_at_initial_pathologic_diagnosis', "censor (alive=0; dead=1)": "alive"}, inplace=True)
# cgga_data_mRNAseq_pheno["time"] = cgga_data_pheno["time"]*30
cgga_data_mRNA_array_pheno["bcr_patient_barcode"] = cgga_data_mRNA_array_pheno.index
cgga_data_mRNA_array_pheno
# Out:
#           tcga_subtypes   prs_type histology   grade  gender  \
# CGGA_ID
# CGGA_11       Classical    Primary       GBM  WHO IV  Female
# CGGA_124    Mesenchymal    Primary       GBM  WHO IV    Male
# CGGA_126    Mesenchymal    Primary       GBM  WHO IV  Female
# CGGA_168    Mesenchymal    Primary       GBM  WHO IV    Male
# CGGA_172    Mesenchymal    Primary       GBM  WHO IV  Female
# ...                 ...        ...       ...     ...     ...
# CGGA_719         Neural  Secondary      sGBM  WHO IV    Male
# CGGA_798    Mesenchymal  Secondary      sGBM  WHO IV  Female
# CGGA_822      Proneural  Secondary      sGBM  WHO IV    Male
# CGGA_899      Proneural  Recurrent      rGBM  WHO IV    Male
# CGGA_1068   Mesenchymal  Secondary      sGBM  WHO IV    Male
#
#            age_at_initial_pathologic_diagnosis    time  alive  \
# CGGA_ID
# CGGA_11                                   57.0   155.0    1.0
# CGGA_124                                  53.0   414.0    1.0
# ...

# %%
cgga_data_mRNA_array_pheno["grade"].unique()
# Out:
# array(['WHO IV', nan, 'WHO II', 'WHO III'], dtype=object)

# %%
filtered_cgga_data_mRNA_array_with_pheno_data = pd.concat([cgga_data_mRNA_array_pheno, filtered_cgga_data_mRNA_array], axis=1)
filtered_cgga_data_mRNA_array_with_pheno_data = filtered_cgga_data_mRNA_array_with_pheno_data[(filtered_cgga_data_mRNA_array_with_pheno_data["grade"] == "WHO III") | (filtered_cgga_data_mRNA_array_with_pheno_data["grade"] == "WHO II")]
filtered_cgga_data_mRNA_array_with_pheno_data
# Out:
#           tcga_subtypes   prs_type histology    grade  gender  \
# CGGA_253      Proneural    Primary         A   WHO II  Female
# CGGA_256         Neural    Primary         A   WHO II    Male
# CGGA_258    Mesenchymal    Primary         A   WHO II  Female
# CGGA_267         Neural    Primary         A   WHO II    Male
# CGGA_271         Neural    Primary         A   WHO II    Male
# ...                 ...        ...       ...      ...     ...
# CGGA_406      Classical  Recurrent       rAA  WHO III  Female
# CGGA_492    Mesenchymal  Recurrent       rAA  WHO III    Male
# CGGA_704      Proneural    Primary         A   WHO II    Male
# CGGA_1061     Proneural  Recurrent       rAA  WHO III  Female
# CGGA_703         Neural  Recurrent       rAO  WHO III  Female
#
#            age_at_initial_pathologic_diagnosis    time  alive  \
# CGGA_253                                  37.0  5159.0    0.0
# CGGA_256                                  39.0   158.0    0.0
# ...

# %%
# Calculate medians for each column
filtered_cgga_data_mRNA_array_with_medians = filtered_cgga_data_mRNA_array_with_pheno_data.copy()
medians = filtered_cgga_data_mRNA_array.median()
cols = filtered_cgga_data_mRNA_array.columns
# Create new columns for each column in the DataFrame
for col in cols:
    new_col_name = col + 'median'
    filtered_cgga_data_mRNA_array_with_medians[new_col_name] = (filtered_cgga_data_mRNA_array[col] > medians[col]).astype(int)
filtered_cgga_data_mRNA_array_with_medians
# Out:
#           tcga_subtypes   prs_type histology    grade  gender  \
# CGGA_253      Proneural    Primary         A   WHO II  Female
# CGGA_256         Neural    Primary         A   WHO II    Male
# CGGA_258    Mesenchymal    Primary         A   WHO II  Female
# CGGA_267         Neural    Primary         A   WHO II    Male
# CGGA_271         Neural    Primary         A   WHO II    Male
# ...                 ...        ...       ...      ...     ...
# CGGA_406      Classical  Recurrent       rAA  WHO III  Female
# CGGA_492    Mesenchymal  Recurrent       rAA  WHO III    Male
# CGGA_704      Proneural    Primary         A   WHO II    Male
# CGGA_1061     Proneural  Recurrent       rAA  WHO III  Female
# CGGA_703         Neural  Recurrent       rAO  WHO III  Female
#
#            age_at_initial_pathologic_diagnosis    time  alive  \
# CGGA_253                                  37.0  5159.0    0.0
# CGGA_256                                  39.0   158.0    0.0
# ...

# %%
filtered_cgga_data_mRNA_array_with_medians.to_csv('cgga_data_mRNA_array.txt', sep='\t', index=False)

# %%
set(filtered_cgga_data_mRNAseq_with_medians["grade"])
# Out:
# {'WHO II', 'WHO III'}

# %%
sum((filtered_cgga_with_pheno_data["grade"] == "II").astype(int))
# Out:
# 291

# %%
sum((filtered_cgga_with_pheno_data["grade"] == "III").astype(int))
# Out:
# 334

# %%
set(filtered_cgga_with_pheno_data["histology"])
# Out:
# {'Anaplastic Astrocytoma',
#  'Anaplastic Oligoastrocytoma',
#  'Anaplastic Oligodendrolgioma',
#  'Astrocytoma',
#  'Oligoastrocytoma',
#  'Oligodendroglioma',
#  nan}
