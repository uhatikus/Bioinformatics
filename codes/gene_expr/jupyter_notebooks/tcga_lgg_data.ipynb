# %%
import pandas as pd
import numpy as np
import sys 
# !{sys.executable} -m pip install openpyxl
import openpyxl
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Looking in indexes: https://pypi.org/simple, https://alexander.ukhatov:****@pypi.pkg.jetbrains.space/glassdomeinc/p/ai/forecast-anomaly-data-science/simple
# ...
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip

# %%
tcga_lgg_data = pd.read_csv("2023-07-31_TCGA_LGG_expression.txt", sep='\t')
tcga_lgg_data.set_index("Sample", inplace=True)

# %%
tcga_lgg_data.head(2)
# Out:
#                   A1BG  A1CF     A2BP1     A2LD1     A2ML1        A2M  \
# Sample
# TCGA.CS.4938  6.563913  -1.0  4.533302  3.805746  7.194794  13.851770
# TCGA.CS.4941  6.184530  -1.0  9.036173  7.175780  9.027613  14.131312
#
#                 A4GALT     A4GNT  AAA1      AAAS  ...     ZXDA      ZXDB  \
# Sample                                            ...
# TCGA.CS.4938  6.207920 -1.000000  -1.0  9.193166  ...  6.01550  9.032542
# TCGA.CS.4941  7.324319  0.618427  -1.0  8.493469  ...  6.73383  8.870561
#
#                    ZXDC    ZYG11A     ZYG11B        ZYX      ZZEF1      ZZZ3  \
# Sample
# TCGA.CS.4938  10.357570 -1.000000  10.547087  10.643323  10.195134  9.708507
# TCGA.CS.4941  10.261164 -0.242806  10.774546  11.925712  10.738286  9.988724
#
#               psiTPTE22  tAKR
# Sample
# TCGA.CS.4938   9.604271  -1.0
# TCGA.CS.4941   4.283818  -1.0
#
# [2 rows x 20501 columns]

# %%
[name for name in cgga_data.columns if "GC0" in name]
# Out:
# []

# %%
"FABP1" in cgga_data.columns
# Out:
# False

# %%
genes = list(set(list(pd.read_excel('gene_list.xlsx', sheet_name=0, header=None)[0]) +\
    list(pd.read_excel('gene_list.xlsx', sheet_name=1, header=None)[0])+\
    list(pd.read_excel('gene_list.xlsx', sheet_name=2, header=None)[0])))

# %%
print(len(genes), "genes: ", genes)
# Out:
# 87 genes:  ['CRHR2', 'CD3D', 'BCL2L11', 'ITPR3', 'ETV4', 'CHIT1', 'KRT19', 'MDFI', 'SPRY4', 'CORO6', 'GPR3', 'RLBP1', 'SKIL', 'LRRK2', 'ALDH1A3', 'BAG3', 'CD36', 'ABCC3', 'ANXA2', 'PGAM2', 'DDRGK1', 'DMRT3', 'ETV5', 'ACTB', 'PHLDB2', 'GNG12', 'APP', 'PLP1', 'MPL', 'GDF15', 'SHC3', 'DPY19L3', 'SPSB1', 'KRT5', 'MYO1D', 'GRB14', 'KCNJ12', 'ALDH8A1', 'FSHR', 'HNF4A', 'CBX3', 'HLA-DQA1', 'MT-ND6', 'P2RY14', 'PREX2', 'AQP1', 'TP53TG5', 'OXGR1', 'SYNJ2', 'NPBWR2', 'FABP1', 'MET', 'SLC9A3R2', 'CFTR', 'THSD7A', 'MT-ND3', 'RAF1', 'DDIT4L', 'PTGDR2', 'TIE1', 'GEM', 'PTH1R', 'PPP5C', 'MYO5C', 'TUBB4A', 'THBS4', 'IGF2BP3', 'CCM2L', 'VAX1', 'PENK', 'EVPL', 'MT-RNR2', 'MYC', 'ESR1', 'BMP8A', 'KRT31', 'C11orf54', 'HTR1B', 'AKR1E2', 'SLC12A7', 'PIM1', 'CKMT2', 'PAX6', 'HTR1F', 'C1QTNF7', 'DLG4', 'PSEN2']

# %%
genes_in_tcga_lgg = [g for g in genes if g in tcga_lgg_data.columns]
genes_not_in_tcga_lgg = [g for g in genes if g not in tcga_lgg_data.columns]
print(f"Not in TCGA LGG: {genes_not_in_tcga_lgg}")
# Out:
# Not in TCGA LGG: ['HLA-DQA1', 'MT-ND6', 'MT-ND3', 'PTGDR2', 'TUBB4A', 'CCM2L', 'MT-RNR2']

# %%
filtered_tcga_lgg_data_pre_log = tcga_lgg_data[genes_in_tcga_lgg]
filtered_tcga_lgg_data = np.exp(filtered_tcga_lgg_data_pre_log)
filtered_tcga_lgg_data
# Out:
#                  CRHR2        CD3D       BCL2L11        ITPR3          ETV4  \
# Sample
# TCGA.CS.4938  0.886103    3.074482   6877.157537   169.507570     81.149775
# TCGA.CS.4941  1.285417  131.885451   4229.327485  1107.846553  12949.024509
# TCGA.CS.4942  0.785629   11.223401  10883.880335  1956.740371      5.520654
# TCGA.CS.4943  0.759108    2.977620   9052.502154   477.009577     23.721410
# TCGA.CS.4944  7.470477   13.415816   2136.880458   325.101521   5165.198517
# ...                ...         ...           ...          ...           ...
# TCGA.WY.A85A  1.891866    1.040352   6047.760664   967.696650     17.816015
# TCGA.WY.A85B  2.317954   13.562955   4728.648564   556.135346     12.203147
# TCGA.WY.A85C  2.197746    0.870991   7100.195709  1751.952895    137.385075
# TCGA.WY.A85D  0.367879    0.367879   6288.604738   564.055536     79.260762
# TCGA.WY.A85E  4.345116    3.515747  11578.309827  1059.225950     24.556078
#
# ...

# %%
tcga_lgg_data_pheno = pd.read_csv("2023-07-31_TCGA_LGG_pheno.txt", sep='\t')
tcga_lgg_data_pheno.set_index("Sample", inplace=True)
print(tcga_lgg_data_pheno.columns)
tcga_lgg_data_pheno
# Out:
# Index(['Histology', 'Recurrence', 'Grade', 'Subtype', 'survival', 'status',
#        'Gender', 'RNASeqCluster', 'MethylationCluster', 'miRNACluster',
#        'CNCluster', 'RPPACluster', 'OncosignCluster', 'COCCluster',
#        'co_del_1p_19q', 'TERT_promoter_status', 'IDH1_status', 'IDH2_status',
#        'TP53_status', 'ATRX_status', 'CIC_status', 'NOTCH1_status',
#        'FUBP1_status', 'PIK3CA_status', 'NF1_status', 'PIK3R1_status',
#        'PTEN_status', 'EGFR_status'],
#       dtype='object')
#                      Histology Recurrence Grade           Subtype  survival  \
# Sample
# TCGA.CS.4938       Astrocytoma    Primary    II  IDHmut-non-codel       4.7
# TCGA.CS.4941       Astrocytoma    Primary   III             IDHwt       7.7
# TCGA.CS.4942       Astrocytoma    Primary   III  IDHmut-non-codel      43.9
# TCGA.CS.4943       Astrocytoma    Primary   III  IDHmut-non-codel      18.1
# TCGA.CS.4944       Astrocytoma    Primary    II  IDHmut-non-codel      10.6
# ...

# %%
tcga_lgg_data_pheno.rename(columns=lambda x: x.lower(), inplace=True)
tcga_lgg_data_pheno.rename(columns={'survival': 'time', 'age': 'age_at_initial_pathologic_diagnosis', "status": "alive"}, inplace=True)
tcga_lgg_data_pheno["time"] = tcga_lgg_data_pheno["time"]*30
tcga_lgg_data_pheno["bcr_patient_barcode"] = tcga_lgg_data_pheno.index
tcga_lgg_data_pheno
# Out:
#                      histology recurrence grade           subtype    time  \
# Sample
# TCGA.CS.4938       Astrocytoma    Primary    II  IDHmut-non-codel   141.0
# TCGA.CS.4941       Astrocytoma    Primary   III             IDHwt   231.0
# TCGA.CS.4942       Astrocytoma    Primary   III  IDHmut-non-codel  1317.0
# TCGA.CS.4943       Astrocytoma    Primary   III  IDHmut-non-codel   543.0
# TCGA.CS.4944       Astrocytoma    Primary    II  IDHmut-non-codel   318.0
# ...                        ...        ...   ...               ...     ...
# TCGA.WY.A85A       Astrocytoma    Primary    II               NaN  1302.0
# TCGA.WY.A85B       Astrocytoma    Primary    II               NaN  1374.0
# TCGA.WY.A85C       Astrocytoma    Primary    II               NaN  1407.0
# TCGA.WY.A85D  Oligoastrocytoma    Primary    II               NaN  1131.0
# TCGA.WY.A85E  Oligoastrocytoma    Primary    II               NaN   624.0
#
# ...

# %%
filtered_tcga_lgg_with_pheno_data = pd.concat([tcga_lgg_data_pheno, filtered_tcga_lgg_data], axis=1)
filtered_tcga_lgg_with_pheno_data = filtered_tcga_lgg_with_pheno_data[filtered_tcga_lgg_with_pheno_data["grade"] != "IV"]
filtered_tcga_lgg_with_pheno_data
# Out:
#                      histology recurrence grade           subtype    time  \
# Sample
# TCGA.CS.4938       Astrocytoma    Primary    II  IDHmut-non-codel   141.0
# TCGA.CS.4941       Astrocytoma    Primary   III             IDHwt   231.0
# TCGA.CS.4942       Astrocytoma    Primary   III  IDHmut-non-codel  1317.0
# TCGA.CS.4943       Astrocytoma    Primary   III  IDHmut-non-codel   543.0
# TCGA.CS.4944       Astrocytoma    Primary    II  IDHmut-non-codel   318.0
# ...                        ...        ...   ...               ...     ...
# TCGA.WY.A85A       Astrocytoma    Primary    II               NaN  1302.0
# TCGA.WY.A85B       Astrocytoma    Primary    II               NaN  1374.0
# TCGA.WY.A85C       Astrocytoma    Primary    II               NaN  1407.0
# TCGA.WY.A85D  Oligoastrocytoma    Primary    II               NaN  1131.0
# TCGA.WY.A85E  Oligoastrocytoma    Primary    II               NaN   624.0
#
# ...

# %%
# Calculate medians for each column
filtered_tcga_lgg_data_with_medians = filtered_tcga_lgg_with_pheno_data.copy()
medians = filtered_tcga_lgg_data.median()
cols = filtered_tcga_lgg_data.columns
# Create new columns for each column in the DataFrame
for col in cols:
    new_col_name = col + 'median'
    filtered_tcga_lgg_data_with_medians[new_col_name] = (filtered_tcga_lgg_data[col] > medians[col]).astype(int)
filtered_tcga_lgg_data_with_medians
# Out:
#                      histology recurrence grade           subtype    time  \
# Sample
# TCGA.CS.4938       Astrocytoma    Primary    II  IDHmut-non-codel   141.0
# TCGA.CS.4941       Astrocytoma    Primary   III             IDHwt   231.0
# TCGA.CS.4942       Astrocytoma    Primary   III  IDHmut-non-codel  1317.0
# TCGA.CS.4943       Astrocytoma    Primary   III  IDHmut-non-codel   543.0
# TCGA.CS.4944       Astrocytoma    Primary    II  IDHmut-non-codel   318.0
# ...                        ...        ...   ...               ...     ...
# TCGA.WY.A85A       Astrocytoma    Primary    II               NaN  1302.0
# TCGA.WY.A85B       Astrocytoma    Primary    II               NaN  1374.0
# TCGA.WY.A85C       Astrocytoma    Primary    II               NaN  1407.0
# TCGA.WY.A85D  Oligoastrocytoma    Primary    II               NaN  1131.0
# TCGA.WY.A85E  Oligoastrocytoma    Primary    II               NaN   624.0
#
# ...

# %%
filtered_tcga_lgg_data_with_medians.to_csv('tcga_lgg_data.txt', sep='\t', index=False)

# %%
set(filtered_cgga_with_pheno_data["grade"])
# Out:
# {'II', 'III', nan}

# %%
sum((filtered_cgga_with_pheno_data["grade"] == "II").astype(int))
# Out:
# 291

# %%
sum((filtered_cgga_with_pheno_data["grade"] == "III").astype(int))
# Out:
# 334

# %%
set(filtered_cgga_with_pheno_data["histology"])
# Out:
# {'Anaplastic Astrocytoma',
#  'Anaplastic Oligoastrocytoma',
#  'Anaplastic Oligodendrolgioma',
#  'Astrocytoma',
#  'Oligoastrocytoma',
#  'Oligodendroglioma',
#  nan}
