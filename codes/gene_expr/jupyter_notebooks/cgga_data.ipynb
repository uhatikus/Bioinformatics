# %%
import pandas as pd
import numpy as np
import sys 
# !{sys.executable} -m pip install openpyxl
import openpyxl
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Looking in indexes: https://pypi.org/simple, https://alexander.ukhatov:****@pypi.pkg.jetbrains.space/glassdomeinc/p/ai/forecast-anomaly-data-science/simple
# ...
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip

# %%
cgga_data = pd.read_csv("2023-07-25_CGGA_expression.txt", sep='\t')
cgga_data.set_index("Sample", inplace=True)

# %%
cgga_data.head(2)
# Out:
#                A1BG  A1BG-AS1       A2M   A2M-AS1     A2ML1     A2MP1  \
# Sample
# CGGA_1001  3.715893  1.389567  8.824704  1.925999 -0.888969 -0.454032
# CGGA_1002  6.111657  2.121015  6.749936 -0.473931  0.333424 -0.415037
#
#             A3GALT2    A4GALT      AAAS      AACS  ...    ZWILCH     ZWINT  \
# Sample                                             ...
# CGGA_1001 -1.000000  2.060047  4.822220  2.087463  ...  1.847997  1.464668
# CGGA_1002 -0.862496  2.226509  5.147307  5.078524  ...  1.831877  2.952334
#
#                ZXDA      ZXDB      ZXDC    ZYG11A    ZYG11B       ZYX  \
# Sample
# CGGA_1001  0.575312  0.871844  3.160275 -0.943416  2.107688  7.311612
# CGGA_1002  0.042644  1.063503  2.715893 -0.943416  2.464668  6.664198
#
#               ZZEF1      ZZZ3
# Sample
# CGGA_1001  2.819668  2.726831
# CGGA_1002  2.724650  3.863938
#
# [2 rows x 23271 columns]

# %%
[name for name in cgga_data.columns if "GC0" in name]
# Out:
# []

# %%
"FABP1" in cgga_data.columns
# Out:
# False

# %%
genes = list(set(list(pd.read_excel('gene_list.xlsx', sheet_name=0, header=None)[0]) +\
    list(pd.read_excel('gene_list.xlsx', sheet_name=1, header=None)[0])+\
    list(pd.read_excel('gene_list.xlsx', sheet_name=2, header=None)[0])))

# %%
print(len(genes), "genes: ", genes)
# Out:
# 87 genes:  ['ETV4', 'NPBWR2', 'HTR1F', 'CFTR', 'MT-ND3', 'THSD7A', 'ACTB', 'APP', 'HLA-DQA1', 'HNF4A', 'SLC12A7', 'KRT5', 'PIM1', 'KRT31', 'ALDH8A1', 'KRT19', 'BAG3', 'GPR3', 'P2RY14', 'ABCC3', 'TIE1', 'THBS4', 'CD3D', 'CHIT1', 'GDF15', 'C1QTNF7', 'PREX2', 'ITPR3', 'CD36', 'RLBP1', 'ETV5', 'DDRGK1', 'IGF2BP3', 'C11orf54', 'SHC3', 'PTGDR2', 'MPL', 'MET', 'CRHR2', 'TP53TG5', 'FABP1', 'ESR1', 'TUBB4A', 'CCM2L', 'FSHR', 'MYO5C', 'PPP5C', 'BMP8A', 'SKIL', 'HTR1B', 'PHLDB2', 'PTH1R', 'AKR1E2', 'GRB14', 'SPRY4', 'PLP1', 'KCNJ12', 'MT-RNR2', 'OXGR1', 'GNG12', 'LRRK2', 'CBX3', 'DLG4', 'DMRT3', 'VAX1', 'DPY19L3', 'ALDH1A3', 'EVPL', 'MYC', 'SPSB1', 'GEM', 'DDIT4L', 'CKMT2', 'ANXA2', 'CORO6', 'AQP1', 'BCL2L11', 'MT-ND6', 'PENK', 'RAF1', 'PGAM2', 'PSEN2', 'MDFI', 'SYNJ2', 'MYO1D', 'PAX6', 'SLC9A3R2']

# %%
genes_in_cgga = [g for g in genes if g in cgga_data.columns]
genes_not_in_cgga = [g for g in genes if g not in cgga_data.columns]
print(f"Not in CGGA: {genes_not_in_cgga}")
# Out:
# Not in CGGA: ['NPBWR2', 'FABP1', 'FSHR', 'AQP1']

# %%
filtered_cgga_data_pre_log = cgga_data[genes_in_cgga]
filtered_cgga_data = np.exp(filtered_cgga_data_pre_log)
filtered_cgga_data
# Out:
#                 ETV4     HTR1F      CFTR        MT-ND3    THSD7A  \
# Sample
# CGGA_1001   4.785532  0.501747  0.400142  9.070955e+05  0.513464
# CGGA_1002   6.245600  0.525263  0.573273  2.858296e+06  1.363889
# CGGA_1003   1.427813  0.422107  0.389296  8.251642e+06  3.017222
# CGGA_1004   4.508168  0.422107  0.367879  7.999917e+05  4.416850
# CGGA_1005   0.537144  0.573273  1.132387  7.603541e+05  8.926584
# ...              ...       ...       ...           ...       ...
# CGGA_P87   10.490785  0.660316  0.411079  9.710966e+06  0.858986
# CGGA_P89    3.968990  0.790994  0.378541  7.488197e+05  8.146683
# CGGA_P93    0.685868  0.444428  0.635063  1.618943e+06  6.119443
# CGGA_P98   14.393210  0.411079  0.389296  1.357072e+07  1.285261
# CGGA_P99    1.743363  0.400142  0.389296  3.953297e+06  0.764283
#
#                     ACTB           APP      HLA-DQA1     HNF4A    SLC12A7  \
# Sample
# CGGA_1001  279745.039745   8229.419920  10327.144080  0.400142  40.869873
# ...

# %%
cgga_data_pheno = pd.read_csv("2023-07-25_CGGA_pheno.txt", sep='\t')
cgga_data_pheno.set_index("Sample", inplace=True)

# %%
cgga_data_pheno.rename(columns=lambda x: x.lower(), inplace=True)
cgga_data_pheno.rename(columns={'survival': 'time', 'age': 'age_at_initial_pathologic_diagnosis', "status": "alive"}, inplace=True)
cgga_data_pheno["time"] = cgga_data_pheno["time"]*30
cgga_data_pheno["bcr_patient_barcode"] = cgga_data_pheno.index
cgga_data_pheno
# Out:
#                         histology grade recurrence      subtype  cimp_status  \
# Sample
# CGGA_1001                     GBM    IV    Primary  Mesenchymal          NaN
# CGGA_1002  Anaplastic Astrocytoma   III    Primary    Proneural          NaN
# CGGA_1003       Oligodendroglioma    II    Primary          NaN          NaN
# CGGA_1004             Astrocytoma    II    Primary  Mesenchymal          NaN
# CGGA_1005             Astrocytoma    II    Primary          NaN          NaN
# ...                           ...   ...        ...          ...          ...
# CGGA_P87                      GBM    IV  Recurrent          NaN          NaN
# CGGA_P89                      GBM    IV  Recurrent    Classical          NaN
# CGGA_P93              Astrocytoma    II    Primary          NaN          NaN
# CGGA_P98   Anaplastic Astrocytoma   III  Recurrent          NaN          NaN
# CGGA_P99                      GBM    IV  Recurrent          NaN          NaN
#
# ...

# %%
filtered_cgga_with_pheno_data = pd.concat([cgga_data_pheno, filtered_cgga_data], axis=1)
filtered_cgga_with_pheno_data = filtered_cgga_with_pheno_data[final_ccga["grade"] != "IV"]
filtered_cgga_with_pheno_data
# Out:
#                         histology grade recurrence      subtype  cimp_status  \
# Sample
# CGGA_1002  Anaplastic Astrocytoma   III    Primary    Proneural          NaN
# CGGA_1003       Oligodendroglioma    II    Primary          NaN          NaN
# CGGA_1004             Astrocytoma    II    Primary  Mesenchymal          NaN
# CGGA_1005             Astrocytoma    II    Primary          NaN          NaN
# CGGA_1006  Anaplastic Astrocytoma   III    Primary  Mesenchymal          NaN
# ...                           ...   ...        ...          ...          ...
# CGGA_P83              Astrocytoma    II    Primary          NaN          NaN
# CGGA_P84              Astrocytoma    II    Primary          NaN          NaN
# CGGA_P86        Oligodendroglioma    II    Primary          NaN          NaN
# CGGA_P93              Astrocytoma    II    Primary          NaN          NaN
# CGGA_P98   Anaplastic Astrocytoma   III  Recurrent          NaN          NaN
#
# ...

# %%
# Calculate medians for each column
filtered_cgga_data_with_medians = filtered_cgga_with_pheno_data.copy()
medians = filtered_cgga_data.median()
cols = filtered_cgga_data.columns
# Create new columns for each column in the DataFrame
for col in cols:
    new_col_name = col + 'median'
    filtered_cgga_data_with_medians[new_col_name] = (filtered_cgga_data[col] > medians[col]).astype(int)
filtered_cgga_data_with_medians
# Out:
#                         histology grade recurrence      subtype  cimp_status  \
# Sample
# CGGA_1002  Anaplastic Astrocytoma   III    Primary    Proneural          NaN
# CGGA_1003       Oligodendroglioma    II    Primary          NaN          NaN
# CGGA_1004             Astrocytoma    II    Primary  Mesenchymal          NaN
# CGGA_1005             Astrocytoma    II    Primary          NaN          NaN
# CGGA_1006  Anaplastic Astrocytoma   III    Primary  Mesenchymal          NaN
# ...                           ...   ...        ...          ...          ...
# CGGA_P83              Astrocytoma    II    Primary          NaN          NaN
# CGGA_P84              Astrocytoma    II    Primary          NaN          NaN
# CGGA_P86        Oligodendroglioma    II    Primary          NaN          NaN
# CGGA_P93              Astrocytoma    II    Primary          NaN          NaN
# CGGA_P98   Anaplastic Astrocytoma   III  Recurrent          NaN          NaN
#
# ...

# %%
filtered_cgga_data_with_medians.to_csv('cgga_data.txt', sep='\t', index=False)

# %%
set(filtered_cgga_with_pheno_data["grade"])
# Out:
# {'II', 'III', nan}

# %%
sum((filtered_cgga_with_pheno_data["grade"] == "II").astype(int))
# Out:
# 291

# %%
sum((filtered_cgga_with_pheno_data["grade"] == "III").astype(int))
# Out:
# 334

# %%
set(filtered_cgga_with_pheno_data["histology"])
# Out:
# {'Anaplastic Astrocytoma',
#  'Anaplastic Oligoastrocytoma',
#  'Anaplastic Oligodendrolgioma',
#  'Astrocytoma',
#  'Oligoastrocytoma',
#  'Oligodendroglioma',
#  nan}
